# %%
#Connor Oh
#BME-361
#HW2

# %%
from tkinter import *
from random import *

import tkinter as tk
import random as random

# Create the Tkinter window
window = Tk()

# Define the size of the window
window.geometry("1920x1080")

# Title of the window
window.title("Lottery.exe")

# Canvas - used to help center widgets
can1 = Canvas(window, height=300, width=1152)
can2 = Canvas(window, height=300, width=1152)

#Game Label
game_label = Label(window, text = "Test Your Luck", font=("Arial Bold", 25))
game_label.place(relx=.5, rely=.1,  anchor=CENTER)

# Initialize the text boxes that will display the numbers
label1 = Label(can1, height= 10, width= 10, padx = 2, pady= 2, relief="raised", bg="white", fg = "black", font=("Arial Bold", 20))
label1.grid(row=2, column=0, sticky = W, pady = 2, padx=5)



label2 = Label(can1, height= 10, width= 10, padx = 2, pady= 2, relief="raised", bg="white", fg = "black", font=("Arial Bold", 20))
label2.grid(row=2, column=1, sticky = W, pady = 2, padx=5)


label3 = Label(can1, height= 10, width= 10, padx = 2, pady= 2, relief="raised", bg="white", fg = "black", font=("Arial Bold", 20))
label3.grid(row=2, column=2, sticky = W, pady = 2, padx=5)


label4 = Label(can1, height= 10, width= 10, padx = 2, pady= 2, relief="raised", bg="white", fg = "black", font=("Arial Bold", 20))
label4.grid(row=2, column=3, sticky = W, pady = 2, padx=5)


label5 = Label(can1, height= 10, width= 10, padx = 2, pady= 2, relief="raised", bg="white", fg = "black", font=("Arial Bold", 20))
label5.grid(row=2, column=4, sticky = W, pady = 2, padx=5)


label6 = Label(can1, height= 10, width= 10, padx = 2, pady= 2, bg= "red", fg = "white", relief="raised", font=("Arial Bold", 20))
label6.grid(row=2, column=5, sticky = W, pady = 2, padx=5)

can1.place(relx=0.5, rely=0.3, anchor=CENTER)

# Initialize the text boxes that will display the numbers
label7 = Label(can2, height= 10, width= 10, padx = 2, pady= 2, relief="raised", bg="white", fg = "black", font=("Arial Bold", 20))
label7.grid(row=2, column=0, sticky = W, pady = 2, padx=5)


label8 = Label(can2, height= 10, width= 10, padx = 2, pady= 2, relief="raised", bg="white", fg = "black", font=("Arial Bold", 20))
label8.grid(row=2, column=1, sticky = W, pady = 2, padx=5)


label9 = Label(can2, height= 10, width= 10, padx = 2, pady= 2, relief="raised", bg="white", fg = "black", font=("Arial Bold", 20))
label9.grid(row=2, column=2, sticky = W, pady = 2, padx=5)


label10 = Label(can2, height= 10, width= 10, padx = 2, pady= 2, relief="raised", bg="white", fg = "black", font=("Arial Bold", 20))
label10.grid(row=2, column=3, sticky = W, pady = 2, padx=5)


label11 = Label(can2, height= 10, width= 10, padx = 2, pady= 2, relief="raised", bg="white", fg = "black", font=("Arial Bold", 20))
label11.grid(row=2, column=4, sticky = W, pady = 2, padx=5)


label12= Label(can2, height= 10, width= 10, padx = 2, pady= 2, bg= "red", fg = "white", relief="raised", font=("Arial Bold", 20))
label12.grid(row=2, column=5, sticky = W, pady = 2, padx=5)

can2.place(relx=0.5, rely=0.75, anchor=CENTER)

labels = [label1, label2, label3, label4, label5, label6, label7, label8, label9, label10, label11, label12]

# function to actually do the numbers
def showMeTheMoney ():
    winningNums = []
    i=0
    for label in labels:
        if i!=5 or i !=11:
            newWinningNum = random.randint(1,69)
            while newWinningNum in winningNums:
                newWinningNum = random.randint(1,69)
            winningNums.append(newWinningNum)
            labels[i].config(text=newWinningNum)
        else:
            newWinningNum = random.randint(1,26)
            labels[i].config(text=newWinningNum)
        i+=1
   # print (winningNums)
        
# Make and place button
button1 = Button(text='Spin It!', command = showMeTheMoney, height = 5, width = 20)
button1.place(relx=0.5, rely=0.525, anchor=CENTER)
            
# showMeTheMoney()

    
window.mainloop()
