# %%
for row in range(0,15):
    for col in range(0,30):
        if row == 0:
            # first row of image
            if (col < 5) or (col>=23):
                print("░",end="")
            if (col >= 5 and col < 9) or (col >= 17 and col < 23):
                print("▄",end="")
            if col >=9 and col < 17:
                print("▀",end="")
        elif row == 1:
            # second row of image
            if (col < 5) or (col>=6 and col<10) or (col>=22 and col<24) or (col>=27):
                print("░",end="")
            if col == 26:
                print("▄",end="")
            if col >=24 and col < 26:
                print("▀",end="")
            if col == 5:
                print("█",end="")
            if (col>=10 and col < 22):
                print("▒",end="")
        elif row == 2:
            # third row of image
            if (col < 4) or (col>=5 and col<8) or (col>=14 and col<22) or (col>=25 and col<27) or (col>=28):
                print("░",end="")
            if col == 4 or col == 27:
                print("█",end="")
            if (col>=8 and col < 14) or (col>=22 and col <25):
                print("▒",end="")
        elif row == 3:
            # fourth row of image
            if (col < 3) or (col>=4 and col<10) or (col>=16 and col<21) or (col>=24 and col<28) or (col>=29):
                print("░",end="")
            if col == 10 or (col>=14 and col<16) or (col>=21 and col<24):
                print("▄",end="")
            if col == 13:
                print("▀",end="")
            if col == 3 or (col>=11 and col<13) or col == 28:
                print("█",end="")
        elif row == 4:
            if(col==0):
                print("░▄▀▒▄▄▄▒░█▀▀▀▀▄▄█░░░██▄▄█░░░░█░",end="")
        elif row == 5:
            if(col==0):
                print("█░▒█▒▄░▀▄▄▄▀░░░░░░░░█░░░▒▒▒▒▒░█",end="")
        elif row == 6:
            if(col==0):
                print("█░▒█░█▀▄▄░░░░░█▀░░░░▀▄░░▄▀▀▀▄▒█",end="")
        elif row == 7:
            if(col==0):
                print("░█░▀▄░█▄░█▀▄▄░▀░▀▀░▄▄▀░░░░█░░█░",end="")
        elif row == 8:
            if(col==0):
                print("░░█░░░▀▄▀█▄▄░█▀▀▀▄▄▄▄▀▀█▀██░█░░",end="")
        elif row == 9:
            if(col==0):
                print("░░░█░░░░██░░▀█▄▄▄█▄▄█▄████░█░░░",end="")
        elif row == 10:
            if(col==0):
                print("░░░░█░░░░▀▀▄░█░░░█░█▀██████░█░░",end="")
        elif row == 11:
            if(col==0):
                print("░░░░░▀▄░░░░░▀▀▄▄▄█▄█▄█▄█▄▀░░█░░",end="")
        elif row == 12:
            if(col==0):
                print("░░░░░░░▀▄▄░▒▒▒▒░░░░░░░░░░▒░░░█░",end="")
        elif row == 13:
            if(col==0):
                print("░░░░░░░░░░▀▀▄▄░▒▒▒▒▒▒▒▒▒▒░░░░█░",end="")
        else:
            if(col==0):
                print("░░░░░░░░░░░░░░▀▄▄▄▄▄░░░░░░░░█░░",end="")
        
    print()
# Out:
# ░░░░░▄▄▄▄▀▀▀▀▀▀▀▀▄▄▄▄▄▄░░░░░░░
# ░░░░░█░░░░▒▒▒▒▒▒▒▒▒▒▒▒░░▀▀▄░░░
# ░░░░█░░░▒▒▒▒▒▒░░░░░░░░▒▒▒░░█░░
# ░░░█░░░░░░▄██▀▄▄░░░░░▄▄▄░░░░█░
# ░▄▀▒▄▄▄▒░█▀▀▀▀▄▄█░░░██▄▄█░░░░█░
# █░▒█▒▄░▀▄▄▄▀░░░░░░░░█░░░▒▒▒▒▒░█
# █░▒█░█▀▄▄░░░░░█▀░░░░▀▄░░▄▀▀▀▄▒█
# ░█░▀▄░█▄░█▀▄▄░▀░▀▀░▄▄▀░░░░█░░█░
# ░░█░░░▀▄▀█▄▄░█▀▀▀▄▄▄▄▀▀█▀██░█░░
# ░░░█░░░░██░░▀█▄▄▄█▄▄█▄████░█░░░
# ░░░░█░░░░▀▀▄░█░░░█░█▀██████░█░░
# ░░░░░▀▄░░░░░▀▀▄▄▄█▄█▄█▄█▄▀░░█░░
# ░░░░░░░▀▄▄░▒▒▒▒░░░░░░░░░░▒░░░█░
# ░░░░░░░░░░▀▀▄▄░▒▒▒▒▒▒▒▒▒▒░░░░█░
# ░░░░░░░░░░░░░░▀▄▄▄▄▄░░░░░░░░█░░
